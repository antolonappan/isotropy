# %%
from marcia import Sampler
import os
# %matplotlib inline

# %%
chaindir = 'Chains'
os.makedirs(chaindir, exist_ok=True)

# %%
Samp = Sampler('LCDM',['H0','Omega_m'],['Pantheon_plus'],[70,0.25],sampler_file='Chains/Pantheon_LCDM.h5',max_n=10000)

# %%
Samp.corner_plot()
# Out:
# Already completed 10000 iterations

# %%
Samp = Sampler('wCDM',['H0','Omega_m','w0'],['Pantheon_plus'],[70,0.25,-1],sampler_file='Chains/Pantheon_wCDM.h5',max_n=10000)

# %%
Samp.corner_plot()
# Out:
# Already completed 10000 iterations
# WARNING:chainconsumer:Parameter $w_0$ in chain Chain 0 is not constrained

# %%
Samp = Sampler('CPL',['H0','Omega_m','w0','wa'],['Pantheon_plus'],[70,0.25,-1,0],sampler_file='Chains/Pantheon_CPL.h5',max_n=10000)

# %%
Samp.corner_plot()
# Out:
# Already completed 10000 iterations
# WARNING:chainconsumer:Parameter $w_a$ in chain Chain 0 is not constrained
