# %%
from marcia import Sampler
import os
# %matplotlib inline

# %%
chaindir = 'Chains'
os.makedirs(chaindir, exist_ok=True)

# %%
Samp = Sampler('LCDM',['H0','Omega_m'],['Pantheon_plus'],[70,0.25],sampler_file='Chains/Pantheon_LCDM.h5',resume=False,max_n=10000)

# %%
Samp.corner_plot()

# %%
Samp = Sampler('wCDM',['H0','Omega_m','w0'],['Pantheon_plus'],[70,0.25,-1],sampler_file='Chains/Pantheon_wCDM.h5',resume=False,max_n=10000)

# %%
Samp.corner_plot()
# Out:
# Best-fit values: [75.05308652  0.33153699 -0.85824864]
# Max-Likelihood value (including prior likelihood):-701.4612684542369
# 100%|██████████| 10000/10000 [1:02:48<00:00,  2.65it/s]

# %%
Samp = Sampler('CPL',['H0','Omega_m','w0','wa'],['Pantheon_plus'],[70,0.25,-1,0],sampler_file='Chains/Pantheon_CPL.h5',resume=False,max_n=10000)

# %%
Samp.corner_plot()
