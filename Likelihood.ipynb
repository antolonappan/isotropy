# %%
import sys
sys.path.append('../marcia')

# %%
from marcia import Sampler
import os
# %matplotlib inline

# %%
lcdm = Sampler('LCDM',['H0','Omega_m'],['Pantheon_plus'],[70,0.25],sampler_file='Chains/PantheonPlus_LCDM.h5',max_n=2000)
s = lcdm.sampler()
lcdm.corner_plot()
# Out:
# Already completed 2000 iterations
# Burn-in: 54 and thin: 13

# %%
lcdm = Sampler('LCDM',['H0','Omega_m'],['Pantheon_old'],[70,0.25],sampler_file='Chains/PantheonOld_LCDM.h5',max_n=2000)
s = lcdm.sampler()
lcdm.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [75.05285187  0.29435921]
# Max-Likelihood value (including prior likelihood): -504.7226320685814
# 100%|██████████| 2000/2000 [18:41<00:00,  1.78it/s]
# Burn-in: 52 and thin: 13

# %%
lcdm = Sampler('LCDM',['H0','Omega_m','qso_sigma','qso_beta','qso_gamma'],['Pantheon_plus','QSO_full'],[70,0.25,0.2,6.4,0.6],sampler_file='Chains/PantheonPlusQSO_LCDM.h5',max_n=2000)
s = lcdm.sampler()
lcdm.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [74.80833517  0.35386948  0.22959623  6.39631449  0.66122882]
# Max-Likelihood value (including prior likelihood): -668.0808637381331
# 100%|██████████| 2000/2000 [52:36<00:00,  1.58s/it]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]

# %%
wCDM = Sampler('wCDM',['H0','Omega_m','w0'],['Pantheon_plus'],[70,0.25,-1],sampler_file='Chains/PantheonPlus_wCDM.h5',max_n=2000)
s = wCDM.sampler()
wCDM.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [74.9182228   0.28818787 -0.89402993]
# Max-Likelihood value (including prior likelihood): -701.2338535037326
#   2%|▎         | 50/2000 [00:32<26:39,  1.22it/s]
# 100%|██████████| 2000/2000 [21:48<00:00,  1.53it/s]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]

# %%
wCDM = Sampler('wCDM',['H0','Omega_m','w0'],['Pantheon_old'],[70,0.25,-1],sampler_file='Chains/PantheonOld_wCDM.h5',max_n=2000)
s = wCDM.sampler()
wCDM.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [75.08728567  0.30181706 -1.02063117]
# Max-Likelihood value (including prior likelihood): -504.71755333653664
# 100%|██████████| 2000/2000 [21:53<00:00,  1.52it/s]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]

# %%
wCDM = Sampler('wCDM',['H0','Omega_m','w0','qso_sigma','qso_beta','qso_gamma'],['QSO_full','Pantheon_plus'],[70,0.25,-1,0.2,6.4,0.6],sampler_file='Chains/PantheonPlusQSO_wCDM.h5',max_n=2000)
s = wCDM.sampler()
wCDM.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [75.27901829  0.44401501 -1.3674002   0.22900281  6.5722019   0.65524285]
# Max-Likelihood value (including prior likelihood): -664.998025866333
# 100%|██████████| 2000/2000 [51:30<00:00,  1.55s/it]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]

# %%
cpl =  Sampler('CPL',['H0','Omega_m','w0','wa'],['Pantheon_plus'],[70,0.25,-1,0],sampler_file='Chains/PantheonPlus_CPL.h5',max_n=2000)
s = cpl.sampler()
cpl.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [ 7.49202942e+01  2.88593003e-01 -8.95101567e-01 -4.92198161e-04]
# Max-Likelihood value (including prior likelihood): -701.2339037352064
# 100%|██████████| 2000/2000 [24:30<00:00,  1.36it/s]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]

# %%
cpl =  Sampler('CPL',['H0','Omega_m','w0','wa'],['Pantheon_old'],[70,0.25,-1,0],sampler_file='Chains/PantheonOld_CPL.h5',max_n=2000)
s = cpl.sampler()
cpl.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [ 7.50872852e+01  3.02038344e-01 -1.02097570e+00 -1.39742678e-03]
# Max-Likelihood value (including prior likelihood): -504.7173926779855
# 100%|██████████| 2000/2000 [19:36<00:00,  1.70it/s]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]
# WARNING:chainconsumer:Parameter $\Omega_m$ in chain Chain 0 is not constrained

# %%
cpl =  Sampler('CPL',['H0','Omega_m','w0','wa','qso_sigma','qso_beta','qso_gamma'],['QSO_full','Pantheon_plus'],[70,0.25,-1,0,0.2,6.4,0.6],sampler_file='Chains/PantheonPlusQSO_CPL.h5',max_n=2000)
s = cpl.sampler()
cpl.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [ 7.52778756e+01  4.44214639e-01 -1.36715120e+00 -8.76054222e-03
#   2.29003715e-01  6.57238409e+00  6.55236679e-01]
# Max-Likelihood value (including prior likelihood): -664.9874702574818
# 100%|██████████| 2000/2000 [54:44<00:00,  1.64s/it]
# Autocorrelation time could not be calculated, increase the number of iterations
# Burn-in: 0 and thin: 1[DEFAULT VALUES]
# WARNING:chainconsumer:Parameter $H_0$ in chain Chain 0 is not constrained

# %%
klcdm = Sampler('kLCDM',['H0','Omega_m','Omega_k'],['Pantheon_plus'],[70,0.25,0],sampler_file='Chains/PantheonPlus_kLCDM.h5',max_n=2000)
s = klcdm.sampler()
klcdm.corner_plot()
# Out:
# Already completed 2000 iterations
# Burn-in: 62 and thin: 14

# %%
klcdm = Sampler('kLCDM',['H0','Omega_m','Omega_k'],['Pantheon_old'],[70,0.25,0],sampler_file='Chains/PantheonOld_kLCDM.h5',max_n=2000)
s = klcdm.sampler()
klcdm.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [ 7.50539309e+01  2.94670655e-01 -7.84577924e-04]
# Max-Likelihood value (including prior likelihood): -504.721553194498
# 100%|██████████| 2000/2000 [22:30<00:00,  1.48it/s]
# Burn-in: 67 and thin: 15

# %%
klcdm = Sampler('kLCDM',['H0','Omega_m','Omega_k','qso_sigma','qso_beta','qso_gamma'],['QSO_full','Pantheon_plus'],[70,0.25,0,0.2,6.4,0.6],sampler_file='Chains/PantheonPlusQSO_kLCDM.h5',max_n=2000)
s = klcdm.sampler()
klcdm.corner_plot()
# Out:
# Sampling begins
# Best-fit values: [7.48085506e+01 3.52119906e-01 3.39438960e-03 2.29617316e-01
#  6.39181069e+00 6.61382841e-01]
# Max-Likelihood value (including prior likelihood): -668.2266827438641
#  79%|███████▉  | 1578/2000 [37:52<11:23,  1.62s/it]
