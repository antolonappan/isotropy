# %%
from residual import ResidualStat, ResidualComp
# %matplotlib inline

# %%
res = ResidualStat('LCDM',['H0', 'Omega_m'],'Chains/Pantheon_LCDM.h5')

# %%
res.plot_SN()

# %%
res.plot_residual_hist()

# %%
cls_pos = res.bootstrap(5,5,'position')
# Out:
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 16.71samples/s]

# %%
cls_pix = res.bootstrap(5,5,'pixel')
# Out:
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 57.71samples/s]

# %% [markdown]
# # Comparing

# %%
dic = {'LCDM':{'params':['H0','Omega_m'],'datafile':'Chains/Pantheon_LCDM.h5'},
      'wCDM':{'params':['H0','Omega_m','w0'],'datafile':'Chains/Pantheon_wCDM.h5'}
      }

# %%
respos = ResidualComp(dic,'position',5,5)
respix = ResidualComp(dic,'pixel',5,5)

# %%
respos.run_bootstraping()
# Out:
# Running bootstraping on position for model: LCDM
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 19.97samples/s]
# Running bootstraping on position for model: wCDM
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 19.18samples/s]

# %%
respix.run_bootstraping()
# Out:
# Running bootstraping on pixel for model: LCDM
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 37.94samples/s]
# Running bootstraping on pixel for model: wCDM
# Monte Carlo Samples: 100%|██████████| 5/5 [00:00<00:00, 44.28samples/s]

# %%
respos.plot()

# %%
respix.plot()

# %%
res_ztest = ResidualStat('LCDM',['H0', 'Omega_m'],'Chains/Pantheon_LCDM.h5',zmin=0.1,zmax=0.5)

# %%
res_ztest.plot_SN()
